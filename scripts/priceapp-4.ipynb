# %%
# importing modules
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm

# %%
df_read = pd.read_csv("/Users/harithagb/Downloads/mycsvfile.csv")

# %%
df_read.head(5)
# Out:
#                                         user_name  \
# 0  Will Roadhouse | CEO | Roadhouse International
# 1                                  PlattsburghBTC
# 2                          🌋TripleVolcanoBTCGang🌋
# 3             Zhongshan Liren aka "Sushi Satoshi"
# 4                                 • RIS BIG WIN 🐿
#
#                     user_location  \
# 0  USA & Thailand Hotel Listings
# 1                 Plattsburgh, NY
# 2                        teh Mewn
# 3                       Hong Kong
# 4  Calabarzon, Republic of the Ph
#
#                                     user_description         user_created  \
# 0  USA - Thailand - Costa Rica\nOff-Market Hotel ...  2009-03-16 18:36:15
# 1  ฿ miner that sells extra GH, so come mine with...  2015-08-29 17:25:50
# 2  Volcano Pleb. 39.9K #BTC Gang forever. Tweets ...  2020-05-31 02:08:03
# 3  Love #bitcoin #ethereum\nHourly chart analysis...  2012-02-11 06:43:12
# 4                                             MA•PA💛  2018-01-13 07:25:36
#
# ...

# %%
df_add = pd.read_csv("/Users/harithagb/Downloads/BTC-USD-3.csv")

# %%
df_add.head(5)
# Out:
#          Date          Open          High           Low         Close  \
# 0  2021-07-01  35035.984375  35035.984375  32883.781250  33572.117188
# 1  2021-07-02  33549.601563  33939.589844  32770.679688  33897.046875
# 2  2021-07-03  33854.421875  34909.261719  33402.695313  34668.546875
# 3  2021-07-04  34665.566406  35937.566406  34396.476563  35287.781250
# 4  2021-07-05  35284.343750  35284.343750  33213.660156  33746.003906
#
#       Adj Close       Volume
# 0  33572.117188  37838957079
# 1  33897.046875  38728974942
# 2  34668.546875  24383958643
# 3  35287.781250  24924307911
# 4  33746.003906  26721554282

# %%
# add 6 new empty columns
df_read["high"] = np.nan
df_read["low"] = np.nan
df_read["open"] = np.nan
df_read["close"] = np.nan
df_read["volume"] = np.nan
df_read["adj_close"] = np.nan

# %%
# convert date time to date
df_read["date"] = pd.to_datetime(df_read["date"]).dt.date
df_read.head()
# Out:
#                                         user_name  \
# 0  Will Roadhouse | CEO | Roadhouse International
# 1                                  PlattsburghBTC
# 2                          🌋TripleVolcanoBTCGang🌋
# 3             Zhongshan Liren aka "Sushi Satoshi"
# 4                                 • RIS BIG WIN 🐿
#
#                     user_location  \
# 0  USA & Thailand Hotel Listings
# 1                 Plattsburgh, NY
# 2                        teh Mewn
# 3                       Hong Kong
# 4  Calabarzon, Republic of the Ph
#
#                                     user_description         user_created  \
# 0  USA - Thailand - Costa Rica\nOff-Market Hotel ...  2009-03-16 18:36:15
# 1  ฿ miner that sells extra GH, so come mine with...  2015-08-29 17:25:50
# 2  Volcano Pleb. 39.9K #BTC Gang forever. Tweets ...  2020-05-31 02:08:03
# 3  Love #bitcoin #ethereum\nHourly chart analysis...  2012-02-11 06:43:12
# 4                                             MA•PA💛  2018-01-13 07:25:36
#
# ...

# %%
# convert date time to date
df_add["Date"] = pd.to_datetime(df_add["Date"]).dt.date
df_add.head()
# Out:
#          Date          Open          High           Low         Close  \
# 0  2021-07-01  35035.984375  35035.984375  32883.781250  33572.117188
# 1  2021-07-02  33549.601563  33939.589844  32770.679688  33897.046875
# 2  2021-07-03  33854.421875  34909.261719  33402.695313  34668.546875
# 3  2021-07-04  34665.566406  35937.566406  34396.476563  35287.781250
# 4  2021-07-05  35284.343750  35284.343750  33213.660156  33746.003906
#
#       Adj Close       Volume
# 0  33572.117188  37838957079
# 1  33897.046875  38728974942
# 2  34668.546875  24383958643
# 3  35287.781250  24924307911
# 4  33746.003906  26721554282

# %%
type(df_read['date'])
# Out:
# pandas.core.series.Series

# %%
date = df_read["date"].iloc[2]
entry = df_add.loc[df_add["Date"] == date]

# %%
print(date)
# Out:
# 2021-07-05

# %%
entry
# Out:
#          Date         Open         High           Low         Close  \
# 4  2021-07-05  35284.34375  35284.34375  33213.660156  33746.003906
#
#       Adj Close       Volume
# 4  33746.003906  26721554282

# %%
df_read.at[2, "high"] = entry["High"]
df_read.at[2, "low"] = entry["Low"]
df_read.at[2, "open"] = entry["Open"]
df_read.at[2, "close"] = entry["Close"]
df_read.at[2, "volume"] = entry["Volume"]
df_read.at[2, "adj_close"] = entry["Adj Close"]

print(df_read.iloc[2])
# Out:
# user_name                                      🌋TripleVolcanoBTCGang🌋
# user_location                                                teh Mewn
# user_description    Volcano Pleb. 39.9K #BTC Gang forever. Tweets ...
# user_created                                      2020-05-31 02:08:03
# user_followers                                                  155.0
# user_friends                                                    648.0
# user_favourites                                                7276.0
# user_verified                                                   False
# date                                                       2021-07-05
# text                     #bitcoin #fiat $Link https://t.co/J9nYUQZdsM
# hashtags                                          ['bitcoin', 'fiat']
# source                                             Twitter for iPhone
# is_retweet                                                      False
# ...

# %%
for ind in tqdm(df_read.index):
    date = df_read["date"].iloc[ind]
    entry = df_add.loc[df_add["Date"] == date]
    df_read.at[ind, "high"] = entry["High"]
    df_read.at[ind, "low"] = entry["Low"]
    df_read.at[ind, "open"] = entry["Open"]
    df_read.at[ind, "close"] = entry["Close"]
    df_read.at[ind, "volume"] = entry["Volume"]
    df_read.at[ind, "adj_close"] = entry["Adj Close"]
# Out:
#   0%|          | 0/1586674 [00:00<?, ?it/s]

# %%
df_read.to_csv("final5oct.csv")

# %%
print("conversion done, save done!")
# Out:
# conversion done, save done!
